# %%
import pandas as pd
import numpy as np
import joblib

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

df = pd.read_csv("../data/Sample.csv")

# Drop unnecessary columns
df.drop(["Email", "Name"], axis=1, inplace=True)

# Encode categorical columns
label_encoders = {}

for col in df.select_dtypes(include="object").columns:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le

X = df.drop("Placement(Y/N)?", axis=1)
y = df["Placement(Y/N)?"]

# Scaling
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

joblib.dump(scaler, "../models/scaler.pkl")

# Train Test Split
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled,
    y,
    test_size=0.2,
    random_state=42
)

# ANN Model
model = Sequential([
    Dense(64, activation="relu", input_shape=(X_train.shape[1],)),
    Dense(32, activation="relu"),
    Dense(16, activation="relu"),
    Dense(1, activation="sigmoid")
])

model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

history = model.fit(
    X_train,
    y_train,
    epochs=50,
    batch_size=16,
    validation_split=0.2,
    verbose=1
)

loss, accuracy = model.evaluate(X_test, y_test)

print("Test Accuracy:", accuracy)

model.save("../models/placement_ann.keras")
# Out:
# c:\Users\prabh\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.4883 - loss: 0.6856 - val_accuracy: 0.6562 - val_loss: 0.6378
# Epoch 2/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7656 - loss: 0.6140 - val_accuracy: 0.7969 - val_loss: 0.5980
# Epoch 3/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8477 - loss: 0.5306 - val_accuracy: 0.7969 - val_loss: 0.5487
# Epoch 4/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8867 - loss: 0.4396 - val_accuracy: 0.7969 - val_loss: 0.4985
# Epoch 5/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9062 - loss: 0.3544 - val_accuracy: 0.8594 - val_loss: 0.4612
# Epoch 6/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9062 - loss: 0.3074 - val_accuracy: 0.8438 - val_loss: 0.4705
# Epoch 7/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9102 - loss: 0.2764 - val_accuracy: 0.8594 - val_loss: 0.4562
# Epoch 8/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9062 - loss: 0.2562 - val_accuracy: 0.8594 - val_loss: 0.4753
# Epoch 9/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9102 - loss: 0.2406 - val_accuracy: 0.8594 - val_loss: 0.4803
# Epoch 10/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9141 - loss: 0.2322 - val_accuracy: 0.8594 - val_loss: 0.4922
# Epoch 11/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9141 - loss: 0.2212 - val_accuracy: 0.8438 - val_loss: 0.4787
# Epoch 12/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9180 - loss: 0.2084 - val_accuracy: 0.8594 - val_loss: 0.4949
# Epoch 13/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9141 - loss: 0.1983 - val_accuracy: 0.8594 - val_loss: 0.4966
# Epoch 14/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9219 - loss: 0.1915 - val_accuracy: 0.8594 - val_loss: 0.5024
# Epoch 15/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9219 - loss: 0.1870 - val_accuracy: 0.8594 - val_loss: 0.5087
# Epoch 16/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9219 - loss: 0.1718 - val_accuracy: 0.8594 - val_loss: 0.5216
# Epoch 17/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9375 - loss: 0.1672 - val_accuracy: 0.8594 - val_loss: 0.5405
# Epoch 18/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9375 - loss: 0.1623 - val_accuracy: 0.8438 - val_loss: 0.5444
# Epoch 19/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9336 - loss: 0.1502 - val_accuracy: 0.8594 - val_loss: 0.5522
# Epoch 20/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9531 - loss: 0.1400 - val_accuracy: 0.8594 - val_loss: 0.5612
# Epoch 21/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9531 - loss: 0.1371 - val_accuracy: 0.8438 - val_loss: 0.5679
# Epoch 22/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9648 - loss: 0.1295 - val_accuracy: 0.8594 - val_loss: 0.5833
# Epoch 23/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9609 - loss: 0.1201 - val_accuracy: 0.8594 - val_loss: 0.6167
# Epoch 24/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9688 - loss: 0.1132 - val_accuracy: 0.8594 - val_loss: 0.6202
# Epoch 25/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9805 - loss: 0.1071 - val_accuracy: 0.8594 - val_loss: 0.6148
# Epoch 26/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9766 - loss: 0.1024 - val_accuracy: 0.8594 - val_loss: 0.6627
# Epoch 27/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9766 - loss: 0.0970 - val_accuracy: 0.8594 - val_loss: 0.6462
# Epoch 28/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9805 - loss: 0.0897 - val_accuracy: 0.8594 - val_loss: 0.6828
# Epoch 29/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9844 - loss: 0.0864 - val_accuracy: 0.8438 - val_loss: 0.6747
# Epoch 30/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9883 - loss: 0.0786 - val_accuracy: 0.8594 - val_loss: 0.7170
# Epoch 31/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9844 - loss: 0.0744 - val_accuracy: 0.8594 - val_loss: 0.7063
# Epoch 32/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9844 - loss: 0.0722 - val_accuracy: 0.8438 - val_loss: 0.7438
# Epoch 33/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9883 - loss: 0.0647 - val_accuracy: 0.8594 - val_loss: 0.7487
# Epoch 34/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9844 - loss: 0.0652 - val_accuracy: 0.8750 - val_loss: 0.7936
# Epoch 35/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9805 - loss: 0.0589 - val_accuracy: 0.8438 - val_loss: 0.7675
# Epoch 36/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9961 - loss: 0.0553 - val_accuracy: 0.8594 - val_loss: 0.8185
# Epoch 37/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9961 - loss: 0.0488 - val_accuracy: 0.8594 - val_loss: 0.8202
# Epoch 38/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9961 - loss: 0.0466 - val_accuracy: 0.8438 - val_loss: 0.8378
# Epoch 39/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9922 - loss: 0.0437 - val_accuracy: 0.8438 - val_loss: 0.8399
# Epoch 40/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9961 - loss: 0.0380 - val_accuracy: 0.8594 - val_loss: 0.8820
# Epoch 41/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9961 - loss: 0.0362 - val_accuracy: 0.8594 - val_loss: 0.8873
# Epoch 42/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9961 - loss: 0.0340 - val_accuracy: 0.8594 - val_loss: 0.9318
# Epoch 43/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9961 - loss: 0.0311 - val_accuracy: 0.8594 - val_loss: 0.9458
# Epoch 44/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9961 - loss: 0.0289 - val_accuracy: 0.8594 - val_loss: 0.9543
# Epoch 45/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9961 - loss: 0.0271 - val_accuracy: 0.8594 - val_loss: 0.9720
# Epoch 46/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9961 - loss: 0.0255 - val_accuracy: 0.8594 - val_loss: 0.9861
# Epoch 47/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9961 - loss: 0.0235 - val_accuracy: 0.8438 - val_loss: 1.0371
# Epoch 48/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9961 - loss: 0.0221 - val_accuracy: 0.8594 - val_loss: 1.0068
# Epoch 49/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9961 - loss: 0.0200 - val_accuracy: 0.8438 - val_loss: 1.0743
# Epoch 50/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9961 - loss: 0.0192 - val_accuracy: 0.8594 - val_loss: 1.0826
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8395 - loss: 0.9783
# Test Accuracy: 0.8395061492919922

# %%
joblib.dump(label_encoders, "../models/label_encoders.pkl")
# Out:
# ['../models/label_encoders.pkl']
